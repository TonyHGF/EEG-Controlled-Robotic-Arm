# %%
import numpy as np
import os
import time

# %%
from check_blink import check_blink

# %%
check_blink('G:\\BME1317\\data/eeg_data_10.npy', window_size=250, threshold=0.3, step=25, debug=True)
# Out:
# here (8, 1341)
# No blink detected
# (1341,)
# c:\Users\22020\.conda\envs\bme1317\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\22020\.conda\envs\bme1317\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
